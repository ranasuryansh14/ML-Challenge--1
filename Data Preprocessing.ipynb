# %% [markdown]
# #### Importing Linraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("parkinsons_cleaned.csv")

# %%
df.head(10)
# Out:
#                ID  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  phon_R01_S01_1    119.992    157.302     74.997    0.00784    0.00007
# 1  phon_R01_S01_2    122.400    148.650    113.819    0.00968    0.00008
# 2  phon_R01_S01_3    116.682    131.111    111.555    0.01050    0.00009
# 3  phon_R01_S01_4    116.676    137.871    111.366    0.00997    0.00009
# 4  phon_R01_S01_5    116.014    141.781    110.655    0.01284    0.00011
# 5  phon_R01_S01_6    120.552    131.162    113.787    0.00968    0.00008
# 6  phon_R01_S02_1    120.267    137.244    114.820    0.00333    0.00003
# 7  phon_R01_S02_2    107.332    113.840    104.315    0.00290    0.00003
# 8  phon_R01_S02_3     95.730    132.068     91.754    0.00551    0.00006
# 9  phon_R01_S02_4     95.056    120.103     91.226    0.00532    0.00006
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_14  feature_15  \
# 0    0.00370    0.00554    0.01109    0.04374  ...     0.06545     0.02211
# 1    0.00465    0.00696    0.01394    0.06134  ...     0.09403     0.01929
# 2    0.00544    0.00781    0.01633    0.05233  ...     0.08270     0.01309
# 3    0.00502    0.00698    0.01505    0.05492  ...     0.08771     0.01353
# 4    0.00655    0.00908    0.01966    0.06425  ...     0.10470     0.01767
# 5    0.00463    0.00750    0.01388    0.04701  ...     0.06985     0.01222
# 6    0.00155    0.00202    0.00466    0.01608  ...     0.02337     0.00607
# 7    0.00144    0.00182    0.00431    0.01567  ...     0.02487     0.00344
# 8    0.00293    0.00332    0.00880    0.02093  ...     0.03218     0.01070
# 9    0.00268    0.00332    0.00803    0.02838  ...     0.04324     0.01022
#
#    feature_16  target  feature_18  feature_19  feature_20  feature_21  \
# 0      21.033       1    0.414783    0.815285   -4.813031    0.266482
# 1      19.085       1    0.458359    0.819521   -4.075192    0.335590
# 2      20.651       1    0.429895    0.825288   -4.443179    0.311173
# 3      20.644       1    0.434969    0.819235   -4.117501    0.334147
# 4      19.649       1    0.417356    0.823484   -3.747787    0.234513
# 5      21.378       1    0.415564    0.825069   -4.242867    0.299111
# 6      24.886       1    0.596040    0.764112   -5.634322    0.257682
# 7      26.892       1    0.637420    0.763262   -6.167603    0.183721
# 8      21.812       1    0.615551    0.773587   -5.498678    0.327769
# 9      21.862       1    0.547037    0.798463   -5.011879    0.325996
#
#    feature_22  feature_23
# 0    2.301442    0.284654
# 1    2.486855    0.368674
# 2    2.342259    0.332634
# 3    2.405554    0.368975
# 4    2.332180    0.410335
# 5    2.187560    0.357775
# 6    1.854785    0.211756
# 7    2.064693    0.163755
# 8    2.322511    0.231571
# 9    2.432792    0.271362
#
# [10 rows x 24 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
X = df.drop(columns=['ID', 'target'],axis=1)
y = df['target']

# %%
X
# Out:
#      feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0      119.992    157.302     74.997    0.00784    0.00007    0.00370
# 1      122.400    148.650    113.819    0.00968    0.00008    0.00465
# 2      116.682    131.111    111.555    0.01050    0.00009    0.00544
# 3      116.676    137.871    111.366    0.00997    0.00009    0.00502
# 4      116.014    141.781    110.655    0.01284    0.00011    0.00655
# ..         ...        ...        ...        ...        ...        ...
# 190    174.188    230.978     94.261    0.00459    0.00003    0.00263
# 191    209.516    253.017     89.488    0.00564    0.00003    0.00331
# 192    174.688    240.005     74.287    0.01360    0.00008    0.00624
# 193    198.764    396.961     74.904    0.00740    0.00004    0.00370
# 194    214.289    260.277     77.973    0.00567    0.00003    0.00295
#
#      feature_7  feature_8  feature_9  feature_10  ...  feature_13  feature_14  \
# 0      0.00554    0.01109    0.04374       0.426  ...     0.02971     0.06545
# 1      0.00696    0.01394    0.06134       0.626  ...     0.04368     0.09403
# 2      0.00781    0.01633    0.05233       0.482  ...     0.03590     0.08270
# 3      0.00698    0.01505    0.05492       0.517  ...     0.03772     0.08771
# 4      0.00908    0.01966    0.06425       0.584  ...     0.04465     0.10470
# ..         ...        ...        ...         ...  ...         ...         ...
# 190    0.00259    0.00790    0.04087       0.405  ...     0.02745     0.07008
# 191    0.00292    0.00994    0.02751       0.263  ...     0.01879     0.04812
# 192    0.00564    0.01873    0.02308       0.256  ...     0.01667     0.03804
# 193    0.00390    0.01109    0.02296       0.241  ...     0.01588     0.03794
# 194    0.00317    0.00885    0.01884       0.190  ...     0.01373     0.03078
#
#      feature_15  feature_16  feature_18  feature_19  feature_20  feature_21  \
# 0       0.02211      21.033    0.414783    0.815285   -4.813031    0.266482
# 1       0.01929      19.085    0.458359    0.819521   -4.075192    0.335590
# 2       0.01309      20.651    0.429895    0.825288   -4.443179    0.311173
# 3       0.01353      20.644    0.434969    0.819235   -4.117501    0.334147
# 4       0.01767      19.649    0.417356    0.823484   -3.747787    0.234513
# ..          ...         ...         ...         ...         ...         ...
# 190     0.02764      19.517    0.448439    0.657899   -6.538586    0.121952
# 191     0.01810      19.147    0.431674    0.683244   -6.195325    0.129303
# 192     0.10715      17.883    0.407567    0.655683   -6.787197    0.158453
# 193     0.07223      19.020    0.451221    0.643956   -6.744577    0.207454
# 194     0.04398      21.209    0.462803    0.664357   -5.724056    0.190667
#
#      feature_22  feature_23
# 0      2.301442    0.284654
# 1      2.486855    0.368674
# 2      2.342259    0.332634
# 3      2.405554    0.368975
# 4      2.332180    0.410335
# ..          ...         ...
# 190    2.657476    0.133050
# 191    2.784312    0.168895
# 192    2.679772    0.131728
# 193    2.138608    0.123306
# 194    2.555477    0.148569
#
# [195 rows x 22 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: target, Length: 195, dtype: int64

# %% [markdown]
# ## Spliting Data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size=0.2, random_state=23)

# %%
X_train
# Out:
#      feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 44     243.439    250.912    232.435    0.00210   0.000009    0.00109
# 87     176.281    227.381    125.610    0.00520   0.000030    0.00287
# 99     126.512    141.756     99.770    0.01936   0.000150    0.01159
# 84     176.858    205.560     75.344    0.00747   0.000040    0.00418
# 17     168.778    232.181     75.603    0.00718   0.000040    0.00284
# ..         ...        ...        ...        ...        ...        ...
# 91     151.955    163.335    147.226    0.00419   0.000030    0.00224
# 31     199.228    209.512    192.091    0.00241   0.000010    0.00134
# 182    149.818    163.417    144.786    0.00336   0.000020    0.00174
# 40     186.163    197.724    177.584    0.00298   0.000020    0.00165
# 83      98.804    102.305     87.804    0.00432   0.000040    0.00247
#
#      feature_7  feature_8  feature_9  feature_10  ...  feature_13  feature_14  \
# 44     0.00137    0.00327    0.01419       0.126  ...     0.01033     0.02330
# 87     0.00312    0.00862    0.06511       0.580  ...     0.04683     0.11012
# 99     0.00990    0.03476    0.06734       0.659  ...     0.05783     0.10833
# 84     0.00420    0.01254    0.04795       0.435  ...     0.03510     0.08037
# 17     0.00387    0.00853    0.03327       0.348  ...     0.03430     0.04322
# ..         ...        ...        ...         ...  ...         ...         ...
# 91     0.00227    0.00672    0.07959       0.772  ...     0.05690     0.13262
# 31     0.00138    0.00402    0.01015       0.089  ...     0.00762     0.01513
# 182    0.00198    0.00521    0.02145       0.198  ...     0.01666     0.03464
# 40     0.00175    0.00496    0.01495       0.135  ...     0.01233     0.02321
# 83     0.00258    0.00742    0.02223       0.202  ...     0.01552     0.03831
#
#      feature_15  feature_16  feature_18  feature_19  feature_20  feature_21  \
# 44      0.00454      25.368    0.438296    0.635285   -7.057869    0.091608
# 87      0.04824      13.922    0.602874    0.740837   -5.515071    0.299549
# 99      0.16744      12.435    0.638545    0.674953   -3.760348    0.242861
# 84      0.05470      13.893    0.556494    0.729586   -5.288912    0.343073
# 17      0.02919      20.376    0.631099    0.605417   -2.931070    0.434326
# ..          ...         ...         ...         ...         ...         ...
# 91      0.01658      19.664    0.501037    0.714360   -6.411497    0.207156
# 31      0.00167      30.940    0.432439    0.742055   -7.682587    0.173319
# 182     0.00595      23.008    0.329577    0.757180   -6.277170    0.109397
# 40      0.00231      26.822    0.326480    0.765623   -6.647379    0.201095
# 83      0.00882      22.244    0.576644    0.772416   -6.025367    0.078202
#
#      feature_22  feature_23
# 44     2.330716    0.091470
# 87     3.136550    0.220968
# 99     2.634633    0.378483
# 84     3.099301    0.242119
# 17     3.007463    0.430788
# ..          ...         ...
# 91     2.344876    0.134120
# 31     2.103106    0.068501
# 182    2.209021    0.156368
# 40     2.374073    0.130554
# 83     2.053601    0.177275
#
# [156 rows x 22 columns]

# %%
y_train
# Out:
# 44     0
# 87     1
# 99     1
# 84     1
# 17     1
#       ..
# 91     1
# 31     0
# 182    1
# 40     1
# 83     1
# Name: target, Length: 156, dtype: int64

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %% [markdown]
# ## Data Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Model Training

# %%
# Save processed data
np.save("X_train.npy", X_train)
np.save("X_test.npy", X_test)
np.save("y_train.npy", y_train)
np.save("y_test.npy", y_test)
